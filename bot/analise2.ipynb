# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
tweets_data_path = 'stream_tchau_querida.json'

tweets_data = []
tweets_file = open(tweets_data_path, "r")
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

tweets = pd.DataFrame()

# %%
def get_tw_text(x):
    return x['text']
def get_tw_lang(x):
    return x['text']
def get_tw_country(x):
    return x['text']



#tweets['text'] = map(lambda tweet: tweet['text'], tweets_data)
#tweets['text'] = [get_tw_text for x in tweets_data]
#tweets['lang'] = [str(get_tw_lang) for x in tweets_data]
#tweets['country'] = [get_tw_country for x in tweets_data]

#tweets['text'] = [lambda tw: tw['text'] for x in tweets_data]
tweets['text'] = list(map(lambda tweet: tweet['text'], tweets_data))
tweets['lang'] = [lambda tw: tw['lang'] for x in tweets_data]
#map(lambda tweet: tweet['place']['country'] if tweet['place'] != None else None, tweets_data)
#[x for x in valores if x > 0]
tweets['country'] = [lambda tw: tw['place']['country'] for x in tweets_data]
                      
                      
                      
print(tweets.count())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-909d8db3ee19> in <module>()
#      14
#      15 #tweets['text'] = [lambda tw: tw['text'] for x in tweets_data]
# ---> 16 tweets['text'] = list(map(lambda tweet: tweet['text'], tweets_data))
#      17 tweets['lang'] = [lambda tw: tw['lang'] for x in tweets_data]
#      18 #map(lambda tweet: tweet['place']['country'] if tweet['place'] != None else None, tweets_data)
#
# <ipython-input-73-909d8db3ee19> in <lambda>(tweet)
#      14
#      15 #tweets['text'] = [lambda tw: tw['text'] for x in tweets_data]
# ---> 16 tweets['text'] = list(map(lambda tweet: tweet['text'], tweets_data))
#      17 tweets['lang'] = [lambda tw: tw['lang'] for x in tweets_data]
#      18 #map(lambda tweet: tweet['place']['country'] if tweet['place'] != None else None, tweets_data)
#
# KeyError: 'text'

# %%
tweets_by_lang = tweets['lang'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Languages', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 languages', fontsize=15, fontweight='bold')
tweets_by_lang[:5].plot(ax=ax, kind='bar', color='red')

# %%
tweets_by_country = tweets['country'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Countries', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 countries', fontsize=15, fontweight='bold')
tweets_by_country[:5].plot(ax=ax, kind='bar', color='blue')
